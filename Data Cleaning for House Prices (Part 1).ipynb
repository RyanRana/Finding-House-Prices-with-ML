# %%
# for visualization
import matplotlib.pyplot as plt
import pandas as pd
import csv
# import data
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
import numpy as np

# %%
for i in np.arange(train.shape[1]):
    n = train.iloc[:,i].isnull().sum() 
for i in np.arange(test.shape[1]):
    n = test.iloc[:,i].isnull().sum()

# %%
# keep ID for submission
train_ID = train['Id']
test_ID = test['Id']

# split data for training

X_train = train.drop(['Id'], axis=1)
X_test = test.drop('Id', axis=1)

# dealing with missing data
Xmat = pd.concat([X_train])
Xmat = Xmat.drop(['LotFrontage','MasVnrArea','GarageYrBlt',"Alley"], axis=1)
Xmat = Xmat.fillna(Xmat.median())

# %%
y=train['SalePrice']
Xmat=Xmat['LotArea']

# %%
Xmat = list(Xmat)
Xmat
# Out:
# [8450,
#  9600,
#  11250,
#  9550,
#  14260,
#  14115,
#  10084,
#  10382,
#  6120,
#  7420,
#  11200,
#  11924,
#  12968,
#  10652,
#  10920,
#  6120,
#  11241,
#  10791,
#  13695,
#  7560,
#  14215,
#  7449,
#  9742,
#  4224,
#  8246,
#  14230,
#  7200,
#  11478,
#  16321,
#  6324,
#  8500,
#  8544,
#  11049,
#  10552,
#  7313,
#  13418,
#  10859,
#  8532,
#  7922,
#  6040,
#  8658,
#  16905,
#  9180,
#  9200,
#  7945,
#  7658,
#  12822,
#  11096,
#  4456,
#  7742,
#  13869,
#  6240,
#  8472,
#  50271,
#  7134,
#  10175,
#  2645,
#  11645,
#  13682,
#  7200,
#  13072,
#  7200,
#  6442,
#  10300,
#  9375,
#  9591,
#  19900,
#  10665,
#  4608,
#  15593,
#  13651,
#  7599,
#  10141,
#  10200,
#  5790,
#  1596,
#  8475,
#  8635,
#  10778,
#  10440,
#  13000,
#  4500,
#  10206,
#  8892,
#  8530,
#  16059,
#  11911,
#  3951,
#  8470,
#  8070,
#  7200,
#  8500,
#  13360,
#  7200,
#  9337,
#  9765,
#  10264,
#  10921,
#  10625,
#  9320,
#  10603,
#  9206,
#  7018,
#  10402,
#  7758,
# ...

# %%
y
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
file = open('Clean_Data.csv', 'w+', newline ='') 
  
# writing the data into the file 
with file:     
    write = csv.writer(file) 
    write.writerows(Xmat)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-23-34a8f651ccaf> in <module>
#       4 with file:
#       5     write = csv.writer(file)
# ----> 6     write.writerows(Xmat)
#
# Error: iterable expected, not int

# %%
file = open('Ydata.csv', 'w+', newline ='') 
  
# writing the data into the file 
with file:     
    write = csv.writer(file) 
    write.writerows(y)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-19-1e641b777088> in <module>
#       4 with file:
#       5     write = csv.writer(file)
# ----> 6     write.writerows(y)
#
# Error: iterable expected, not int
